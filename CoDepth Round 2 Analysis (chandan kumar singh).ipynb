# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pr=pd.read_excel('DataAnalyticsProblem.xlsx',sheet_name=['Existing employees','Employees who have left'])

# %%
pr
# Out:
# OrderedDict([('Existing employees',
#                      Emp ID  satisfaction_level  last_evaluation  number_project  \
#               0        2001                0.58             0.74               4
#               1        2002                0.82             0.67               2
#               2        2003                0.45             0.69               5
#               3        2004                0.78             0.82               5
#               4        2005                0.49             0.60               3
#               ...       ...                 ...              ...             ...
#               11423   14207                0.90             0.55               3
#               11424   14208                0.74             0.95               5
#               11425   14209                0.85             0.54               3
#               11426   14210                0.33             0.65               3
# ...

# %%
df=pd.concat(pr[frame] for frame in pr.keys())

# %%
df
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       2001                0.58             0.74               4
# 1       2002                0.82             0.67               2
# 2       2003                0.45             0.69               5
# 3       2004                0.78             0.82               5
# 4       2005                0.49             0.60               3
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      215                   3              0
# ...

# %%
df[df['salary']=='high'].count()
# Out:
# Emp ID                   1237
# satisfaction_level       1237
# last_evaluation          1237
# number_project           1237
# average_montly_hours     1237
# time_spend_company       1237
# Work_accident            1237
# promotion_last_5years    1237
# dept                     1237
# salary                   1237
# dtype: int64

# %%
df[df['salary']=='low'].count()
# Out:
# Emp ID                   7316
# satisfaction_level       7316
# last_evaluation          7316
# number_project           7316
# average_montly_hours     7316
# time_spend_company       7316
# Work_accident            7316
# promotion_last_5years    7316
# dept                     7316
# salary                   7316
# dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x='salary',data=df,palette='RdBu_r')

# %% [markdown]
# # Analysing existing sheet

# %%
pr1=pd.read_excel('DataAnalyticsProblem.xlsx',sheet_name=['Existing employees'])

# %%
pr1
# Out:
# OrderedDict([('Existing employees',
#                      Emp ID  satisfaction_level  last_evaluation  number_project  \
#               0        2001                0.58             0.74               4
#               1        2002                0.82             0.67               2
#               2        2003                0.45             0.69               5
#               3        2004                0.78             0.82               5
#               4        2005                0.49             0.60               3
#               ...       ...                 ...              ...             ...
#               11423   14207                0.90             0.55               3
#               11424   14208                0.74             0.95               5
#               11425   14209                0.85             0.54               3
#               11426   14210                0.33             0.65               3
# ...

# %%
dfe=pd.concat(pr1[frame] for frame in pr1.keys())
dfe
# Out:
#        Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0        2001                0.58             0.74               4
# 1        2002                0.82             0.67               2
# 2        2003                0.45             0.69               5
# 3        2004                0.78             0.82               5
# 4        2005                0.49             0.60               3
# ...       ...                 ...              ...             ...
# 11423   14207                0.90             0.55               3
# 11424   14208                0.74             0.95               5
# 11425   14209                0.85             0.54               3
# 11426   14210                0.33             0.65               3
# 11427   14211                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       215                   3              0
# ...

# %%
dfe['salary']
# Out:
# 0         low
# 1         low
# 2         low
# 3         low
# 4         low
#          ...
# 11423    high
# 11424    high
# 11425    high
# 11426    high
# 11427     low
# Name: salary, Length: 11428, dtype: object

# %%
sns.set_style('whitegrid')
sns.countplot(x='salary',data=dfe,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='promotion_last_5years',data=dfe,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='promotion_last_5years',data=dfe,palette='RdBu_r',hue='salary')

# %%
sns.set_style('whitegrid')
sns.countplot(x='number_project',data=dfe,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='number_project',data=dfe,palette='RdBu_r',hue='salary')

# %%
sns.set_style('whitegrid')
sns.boxplot(y=dfe['satisfaction_level'],data=dfe,hue='salary')

# %%
dfe
# Out:
#        Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0        2001                0.58             0.74               4
# 1        2002                0.82             0.67               2
# 2        2003                0.45             0.69               5
# 3        2004                0.78             0.82               5
# 4        2005                0.49             0.60               3
# ...       ...                 ...              ...             ...
# 11423   14207                0.90             0.55               3
# 11424   14208                0.74             0.95               5
# 11425   14209                0.85             0.54               3
# 11426   14210                0.33             0.65               3
# 11427   14211                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       215                   3              0
# ...

# %%
sns.set_style('whitegrid')
sns.countplot(x='Work_accident',data=dfe,palette='RdBu_r',hue='salary')

# %% [markdown]
# # Analysis for the employees who left

# %%
pr2=pd.read_excel('DataAnalyticsProblem.xlsx',sheet_name=['Employees who have left'])

# %%
pr2
# Out:
# OrderedDict([('Employees who have left',
#                     Emp ID  satisfaction_level  last_evaluation  number_project  \
#               0          1                0.38             0.53               2
#               1          2                0.80             0.86               5
#               2          3                0.11             0.88               7
#               3          4                0.72             0.87               5
#               4          5                0.37             0.52               2
#               ...      ...                 ...              ...             ...
#               3566   14995                0.40             0.57               2
#               3567   14996                0.37             0.48               2
#               3568   14997                0.37             0.53               2
#               3569   14998                0.11             0.96               6
# ...

# %%
dfl=pd.concat(pr2[frame] for frame in pr2.keys())

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
sns.set_style('whitegrid')
sns.countplot(x='salary',data=dfl,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='promotion_last_5years',data=dfl,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='promotion_last_5years',data=dfl,palette='RdBu_r',hue='salary')

# %%
sns.set_style('whitegrid')
sns.countplot(x='number_project',data=dfl,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='number_project',data=dfl,palette='RdBu_r',hue='salary')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Work_accident',data=dfl,palette='RdBu_r',hue='salary')

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
df.groupby(dfl['dept']).count()          #for empolyees who left
# Out:
#              Emp ID  satisfaction_level  last_evaluation  number_project  \
# dept
# IT              546                 546              546             546
# RandD           242                 242              242             242
# accounting      408                 408              408             408
# hr              430                 430              430             430
# management      182                 182              182             182
# marketing       406                 406              406             406
# product_mng     396                 396              396             396
# sales          2028                2028             2028            2028
# support        1110                1110             1110            1110
# technical      1394                1394             1394            1394
#
#              average_montly_hours  time_spend_company  Work_accident  \
# dept
# IT                            546                 546            546
# ...

# %%
df.groupby(dfe['dept']).count()          #for empolyees who are still working
# Out:
#              Emp ID  satisfaction_level  last_evaluation  number_project  \
# dept
# IT             1236                1236             1236            1236
# RandD           911                 911              911             911
# accounting      750                 750              750             750
# hr              712                 712              712             712
# management      632                 632              632             632
# marketing       844                 844              844             844
# product_mng     892                 892              892             892
# sales          4058                4058             4058            4058
# support        2237                2237             2237            2237
# technical      2727                2727             2727            2727
#
#              average_montly_hours  time_spend_company  Work_accident  \
# dept
# IT                           1236                1236           1236
# ...

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
sns.distplot(dfl['average_montly_hours'])

# %%
sns.distplot(dfe['average_montly_hours'])

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
sns.set_style('whitegrid')
sns.boxplot(y=dfe['satisfaction_level'],data=dfl,hue='salary')

# %%
sns.distplot(dfl['last_evaluation'])

# %%
sns.distplot(dfe['last_evaluation'])

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
df.groupby(dfe['dept']).count()
# Out:
#              Emp ID  satisfaction_level  last_evaluation  number_project  \
# dept
# IT             1236                1236             1236            1236
# RandD           911                 911              911             911
# accounting      750                 750              750             750
# hr              712                 712              712             712
# management      632                 632              632             632
# marketing       844                 844              844             844
# product_mng     892                 892              892             892
# sales          4058                4058             4058            4058
# support        2237                2237             2237            2237
# technical      2727                2727             2727            2727
#
#              average_montly_hours  time_spend_company  Work_accident  \
# dept
# IT                           1236                1236           1236
# ...

# %%
df.groupby(dfl['dept']).count()
# Out:
#              Emp ID  satisfaction_level  last_evaluation  number_project  \
# dept
# IT              546                 546              546             546
# RandD           242                 242              242             242
# accounting      408                 408              408             408
# hr              430                 430              430             430
# management      182                 182              182             182
# marketing       406                 406              406             406
# product_mng     396                 396              396             396
# sales          2028                2028             2028            2028
# support        1110                1110             1110            1110
# technical      1394                1394             1394            1394
#
#              average_montly_hours  time_spend_company  Work_accident  \
# dept
# IT                            546                 546            546
# ...

# %%
sns.set_style('whitegrid')
sns.countplot(x='dept',data=dfl,palette='RdBu_r')

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.countplot(x='dept',data=dfl,palette='RdBu_r',hue='salary')

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.countplot(x='dept',data=dfl,palette='RdBu_r',hue='promotion_last_5years')

# %%
dfl
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 3566   14995                0.40             0.57               2
# 3567   14996                0.37             0.48               2
# 3568   14997                0.37             0.53               2
# 3569   14998                0.11             0.96               6
# 3570   14999                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# ...

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.countplot(x='dept',data=dfl,palette='RdBu_r',hue='number_project')

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.countplot(x='dept',data=dfe,palette='RdBu_r',hue='number_project')

# %%
dfe
# Out:
#        Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0        2001                0.58             0.74               4
# 1        2002                0.82             0.67               2
# 2        2003                0.45             0.69               5
# 3        2004                0.78             0.82               5
# 4        2005                0.49             0.60               3
# ...       ...                 ...              ...             ...
# 11423   14207                0.90             0.55               3
# 11424   14208                0.74             0.95               5
# 11425   14209                0.85             0.54               3
# 11426   14210                0.33             0.65               3
# 11427   14211                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       215                   3              0
# ...

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.countplot(x='dept',data=dfe,palette='RdBu_r',hue='salary')

# %%
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.countplot(x='dept',data=dfe,palette='RdBu_r',hue='promotion_last_5years')
